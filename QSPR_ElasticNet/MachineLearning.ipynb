# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("CSV/polymer_functional_groups.csv",encoding ="shift-jis")
feature_names = list(df.columns)[2:]
target = df.columns[1]

# %%
X = df[feature_names] # 説明変数の列を選択
y = df[target]  # 目的変数を選択

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5,random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 重回帰分析の係数 (回帰係数) を取得
coefficients = model.coef_

# 切片を取得
intercept = model.intercept_

# 係数と切片を表示
print("Coefficients:", coefficients)
print("Intercept:", intercept)
#モデルを使用して予測を行う:
# Out:
# Coefficients: [ 1.39270308e+12  1.69311997e+13 -7.81250000e-03 -1.95312500e-03
#   0.00000000e+00  3.88607177e+12  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   2.14515837e+13 -4.59949491e+12  7.19557597e+12  7.19557597e+12
#   2.56038338e+13  0.00000000e+00  0.00000000e+00]
# Intercept: -590605811133776.1

# %%
# 新しいデータポイントに対して予測を行う
y_pred = model.predict(X_test)
plt.scatter(y_test,y_pred)

# %%
from modules  import bayes_EN

# %%
bayes_EN.Elastic_Net(feature_names,X,y,0.5,100)
# Out:
# best value of parameters : {'alpha': 0.9949715532022989, 'rho': 0.030734446163957208}
# Test Score via Optimized Parameters : 0.6543568182776615
